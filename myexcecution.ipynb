# %%
import pandas as pd
df=pd.read_csv('csv1.csv')

# %%
df
# Out:
#     S.NO              NAME      BANK NAME      BRANCH    IFSC CODE  AMOUNT
# 0      1  G.GOPALARATHINAM            BOB   KALAPATTI  BARBOKALCOI    6703
# 1      2    AMIRTHAVALLI.N            BOB   KALAPATTI  BARBOKALCOI       0
# 2      3      JEEVANANTHAM            KVB     TIRUPUR  KVBL0001197    1128
# 3      4         SRIDEVI.C            BOB       SULUR  BARBOSULURX    1225
# 4      5   P. GOVINDHA RAJ            BOB   KALAPATTI  BARBOKALCOI    5510
# 5      6       S.SANGEETHA            BOB   KALAPATTI  BARBOKALCOI     729
# 6      7    SATHIYAPRIYA.K     ICICI BANK   KALAPATTI  ICIC0SF0002   17000
# 7      8      TAMILSELVI.A     ICICI BANK   KALAPATTI  ICICOSF0002  161121
# 8      9         ARCHANA.R    INDIAN BANK   KALAPATTI  IDIB000K162    6250
# 9     10         NIVETHA.G    CANARA BANK  COIMBATORE  CNRB0003557    2275
# 10    11           DEVID.R  INDUSIND BANK  COIMBATORE  INDB0000521    1550

# %%
df[df.BRANCH=='KALLAPATTI']
# Out:
#    S.NO              NAME    BANK NAME     BRANCH    IFSC CODE  AMOUNT
# 0   1.0  G.GOPALARATHINAM          BOB  KALAPATTI  BARBOKALCOI    6703
# 1   2.0    AMIRTHAVALLI.N          BOB  KALAPATTI  BARBOKALCOI       0
# 4   5.0   P. GOVINDHA RAJ          BOB  KALAPATTI  BARBOKALCOI    5510
# 5   6.0       S.SANGEETHA          BOB  KALAPATTI  BARBOKALCOI     729
# 6   7.0    SATHIYAPRIYA.K   ICICI BANK  KALAPATTI  ICIC0SF0002   17000
# 7   8.0      TAMILSELVI.A   ICICI BANK  KALAPATTI  ICICOSF0002  161121
# 8   9.0         ARCHANA.R  INDIAN BANK  KALAPATTI  IDIB000K162    6250

# %%
df[df['BANK NAME']=='BOB']
# Out:
#    S.NO              NAME BANK NAME     BRANCH    IFSC CODE  AMOUNT
# 0   1.0  G.GOPALARATHINAM       BOB  KALAPATTI  BARBOKALCOI    6703
# 1   2.0    AMIRTHAVALLI.N       BOB  KALAPATTI  BARBOKALCOI       0
# 3   4.0         SRIDEVI.C       BOB      SULUR  BARBOSULURX    1225
# 4   5.0   P. GOVINDHA RAJ       BOB  KALAPATTI  BARBOKALCOI    5510
# 5   6.0       S.SANGEETHA       BOB  KALAPATTI  BARBOKALCOI     729

# %%
df.set_index('S.NO',inplace=True)

# %%
df
# Out:
#                   NAME      BANK NAME      BRANCH    IFSC CODE  AMOUNT
# S.NO
# 1.0   G.GOPALARATHINAM            BOB   KALAPATTI  BARBOKALCOI    6703
# 2.0     AMIRTHAVALLI.N            BOB   KALAPATTI  BARBOKALCOI       0
# 3.0       JEEVANANTHAM            KVB     TIRUPUR  KVBL0001197    1128
# 4.0          SRIDEVI.C            BOB       SULUR  BARBOSULURX    1225
# 5.0    P. GOVINDHA RAJ            BOB   KALAPATTI  BARBOKALCOI    5510
# 6.0        S.SANGEETHA            BOB   KALAPATTI  BARBOKALCOI     729
# 7.0     SATHIYAPRIYA.K     ICICI BANK   KALAPATTI  ICIC0SF0002   17000
# 8.0       TAMILSELVI.A     ICICI BANK   KALAPATTI  ICICOSF0002  161121
# 9.0          ARCHANA.R    INDIAN BANK   KALAPATTI  IDIB000K162    6250
# 10.0         NIVETHA.G    CANARA BANK  COIMBATORE  CNRB0003557    2275
# 11.0           DEVID.R  INDUSIND BANK  COIMBATORE  INDB0000521    1550
# NaN                NaN            NaN         NaN        TOTAL  203491

# %%
a=df[df.AMOUNT==df.AMOUNT.max()]

# %%
print(a)
# Out:
#    S.NO          NAME   BANK NAME     BRANCH    IFSC CODE  AMOUNT
# 7     8  TAMILSELVI.A  ICICI BANK  KALAPATTI  ICICOSF0002  161121

# %%
name=a.NAME

# %%
print(name,'has the highest salary')
# Out:
# 7    TAMILSELVI.A
# Name: NAME, dtype: object has the highest salary
